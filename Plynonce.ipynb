# %% [markdown]
# <a href="https://colab.research.google.com/github/bar717171/Bitcoin_Puzzle_Bruteforce/blob/main/Plynonce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://cryptodeeptech.ru/sage-9.3-Ubuntu_20.04-x86_64.tar.bz2
# Out:
# --2024-04-18 05:30:07--  https://cryptodeeptech.ru/sage-9.3-Ubuntu_20.04-x86_64.tar.bz2
# Resolving cryptodeeptech.ru (cryptodeeptech.ru)... 81.177.33.245
# Connecting to cryptodeeptech.ru (cryptodeeptech.ru)|81.177.33.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3024213243 (2.8G) [application/x-bzip2]
# Saving to: ‘sage-9.3-Ubuntu_20.04-x86_64.tar.bz2’
#
# sage-9.3-Ubuntu_20. 100%[===================>]   2.82G  16.1MB/s    in 2m 56s
#
# 2024-04-18 05:33:04 (16.4 MB/s) - ‘sage-9.3-Ubuntu_20.04-x86_64.tar.bz2’ saved [3024213243/3024213243]

# %%
# !tar -xf sage-9.3-Ubuntu_20.04-x86_64.tar.bz2

# %%
cd SageMath/
# Out:
# /content/SageMath

# %%
ls
# Out:
# bootstrap*      configure*                environment.yml  pyrightconfig.json  tox.ini
# build/          configure.ac              local/           README.md           upstream/
# condarc.yml     COPYING.txt               logs/            relocate-once.py*   VERSION.txt
# config/         docker/                   m4/              sage*
# config.status*  environment-optional.yml  Makefile         src/

# %%
# !python3 relocate-once.py
# Out:
# Rewriting paths for your new installation directory
# ===================================================
#
# This might take a few minutes but only has to be done once.
#
# patching b'/content/SageMath/build/make/Makefile-auto'
# patching b'/content/SageMath/build/pkgs/sage_conf/src/build/lib/sage_conf.py'
# patching b'/content/SageMath/build/pkgs/sage_conf/src/build/scripts-3.9/sage-env-config'
# patching b'/content/SageMath/build/pkgs/sage_conf/src/sage_conf.py'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/algebras/finite_dimensional_algebras/finite_dimensional_algebra_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/algebras/letterplace/free_algebra_element_letterplace.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/algebras/letterplace/free_algebra_letterplace.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/algebras/letterplace/letterplace_ideal.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/algebras/lie_algebras/lie_algebra_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/algebras/quatalg/quaternion_algebra_cython.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/algebras/quatalg/quaternion_algebra_element.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/arith/functions.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/arith/multi_modular.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/arith/numerical_approx.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/arith/power.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/arith/rational_reconstruction.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/arith/srange.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/calculus/integration.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/calculus/interpolation.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/calculus/interpolators.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/calculus/ode.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/calculus/riemann.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/calculus/transforms/dwt.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/calculus/transforms/fft.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/calculus/var.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/categories/action.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/categories/category_cy_helper.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/categories/category_singleton.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/categories/coercion_methods.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/categories/examples/semigroups_cython.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/categories/functor.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/categories/map.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/categories/morphism.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/coding/binary_code.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/coding/codecan/autgroup_can_label.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/coding/codecan/codecan.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/coding/kasami_codes.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/combinat_cython.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/crystals/letters.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/crystals/pbw_datum.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/crystals/spins.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/crystals/tensor_product_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/debruijn_sequence.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/degree_sequences.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/designs/designs_pyx.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/designs/evenly_distributed_sets.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/designs/gen_quadrangles_with_spread.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/designs/orthogonal_arrays_find_recursive.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/designs/subhypergraph_search.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/enumeration_mod_permgroup.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/expnums.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/fast_vector_partitions.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/integer_lists/base.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/integer_lists/invlex.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/matrices/dancing_links.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/partitions.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/permutation_cython.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/posets/hasse_cython.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/q_bernoulli.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/rigged_configurations/rigged_partition.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/root_system/braid_orbit.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/root_system/reflection_group_c.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/root_system/reflection_group_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/subword_complex_c.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/words/word_char.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/combinat/words/word_datatypes.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/cpython/atexit.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/cpython/builtin_types.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/cpython/cython_metaclass.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/cpython/debug.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/cpython/dict_del_by_value.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/cpython/getattr.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/cpython/string.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/cpython/type.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/cpython/wrapperdescr.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/crypto/boolean_function.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/data_structures/binary_search.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/data_structures/bitset.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/data_structures/bitset_base.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/data_structures/blas_dict.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/data_structures/bounded_integer_sequences.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/docs/instancedoc.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/dynamics/arithmetic_dynamics/projective_ds_helper.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/dynamics/complex_dynamics/mandel_julia_helper.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/fast_callable.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/fast_eval.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/interp_cc.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/interp_cdf.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/interp_el.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/interp_py.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/interp_rdf.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/interp_rr.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/wrapper_cc.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/wrapper_cdf.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/wrapper_el.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/wrapper_py.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/wrapper_rdf.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/interpreters/wrapper_rr.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/memory.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/ext/memory_allocator.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/finance/fractal.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/finance/markov_multifractal_cython.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/finance/option.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/finance/time_series.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/functions/prime_pi.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/games/sudoku_backtrack.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/integral_points.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/point_collection.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/polyhedron/combinatorial_polyhedron/base.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/polyhedron/combinatorial_polyhedron/combinatorial_face.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/polyhedron/combinatorial_polyhedron/conversions.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/polyhedron/combinatorial_polyhedron/face_iterator.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/polyhedron/combinatorial_polyhedron/face_list_data_structure.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/polyhedron/combinatorial_polyhedron/list_of_faces.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/polyhedron/combinatorial_polyhedron/polyhedron_face_lattice.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/toric_lattice_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/geometry/triangulation/base.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/asteroidal_triples.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/base/boost_graph.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/base/c_graph.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/base/dense_graph.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/base/graph_backends.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/base/sparse_graph.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/base/static_dense_graph.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/base/static_sparse_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/base/static_sparse_graph.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/centrality.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/chrompoly.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/cliquer.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/comparability.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/connectivity.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/convexity_properties.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/distances_all_pairs.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/generators/distance_regular.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/generic_graph_pyx.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/genus.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_coloring.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_decompositions/bandwidth.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_decompositions/clique_separators.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_decompositions/cutwidth.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_decompositions/fast_digraph.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_decompositions/graph_products.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_decompositions/rankwidth.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_decompositions/tree_decomposition.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_decompositions/vertex_separation.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/graph_generators_pyx.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/hyperbolicity.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/independent_sets.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/isoperimetric_inequalities.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/line_graph.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/matchpoly.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/path_enumeration.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/planarity.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/spanning_tree.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/strongly_regular_db.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/traversals.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/trees.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/views.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/graphs/weakly_chordal.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/group.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/libgap_wrapper.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/matrix_gps/group_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/old.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/automorphism_group_canonical_label.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/canonical_augmentation.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/data_structures.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/double_coset.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/refinement_binary.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/refinement_graphs.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/refinement_lists.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/refinement_matrices.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/refinement_python.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref/refinement_sets.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/partn_ref2/refinement_generic.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/perm_gps/permgroup_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/groups/semimonomial_transformations/semimonomial_transformation.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/interacts/library_cython.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/interfaces/process.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/interfaces/sagespawn.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/lfunctions/zero_sums.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/arb/arb_version.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/arb/arith.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/braiding.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ecl.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/eclib/homspace.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/eclib/mat.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/eclib/mwrank.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/eclib/newforms.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/flint/arith.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/flint/flint.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/flint/fmpz_poly.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/gap/element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/gap/libgap.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/gap/util.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/giac/giac.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/glpk/error.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/gmp/pylong.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/gsl/array.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/homfly.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/lcalc/lcalc_Lfunction.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/libecm.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/linbox/linbox_flint_interface.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/lrcalc/lrcalc.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/mpmath/ext_impl.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/mpmath/ext_libmp.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/mpmath/ext_main.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/mpmath/utils.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/convert.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/error.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_GF2.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_GF2E.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_GF2EContext.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_GF2EX.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_GF2X.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_ZZ.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_ZZX.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_ZZ_p.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_ZZ_pContext.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_ZZ_pE.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_ZZ_pEContext.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_ZZ_pEX.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_ZZ_pX.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_lzz_p.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_lzz_pContext.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_lzz_pX.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_mat_GF2.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_mat_GF2E.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ntl/ntl_mat_ZZ.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/pari/convert_flint.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/pari/convert_gmp.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/pari/convert_sage.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/pari/misc.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/pynac/constant.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/pynac/pynac.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/ratpoints.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/readline.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/singular/function.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/singular/groebner_strategy.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/singular/option.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/singular/polynomial.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/singular/ring.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/singular/singular.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/libs/symmetrica/symmetrica.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/action.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/args.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/change_ring.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/constructor.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/echelon_matrix.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix0.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix1.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix2.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_cdv.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_complex_ball_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_complex_double_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_cyclo_dense.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_double_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_gap.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_generic_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_generic_sparse.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_gf2e_dense.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_integer_dense.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_integer_sparse.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_mod2_dense.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_modn_dense_double.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_modn_dense_float.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_modn_sparse.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_mpolynomial_dense.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_polynomial_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_rational_dense.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_rational_sparse.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_real_double_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_sparse.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_symbolic_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/matrix_window.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/misc.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matrix/strassen.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/basis_exchange_matroid.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/basis_matroid.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/circuit_closures_matroid.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/extension.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/lean_matrix.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/linear_matroid.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/matroid.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/set_system.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/union_matroid.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/matroids/unpickling.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/media/channels.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/allocator.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/binary_tree.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/c3.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/c3_controlled.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/cachefunc.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/callable_dict.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/citation.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/classcall_metaclass.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/constant_function.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/derivative.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/fast_methods.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/fpickle.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/function_mangling.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/inherit_comparison.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/lazy_attribute.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/lazy_import.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/lazy_list.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/lazy_string.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/misc_c.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/nested_class.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/parser.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/persist.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/pickle_old.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/randstate.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/reset.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/sage_ostools.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/sage_timeit_class.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/search.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/session.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/stopgap.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/misc/weak_dict.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/arithgroup/arithgroup_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/arithgroup/congroup.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/arithgroup/farey_symbol.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/hypergeometric_misc.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/modform/eis_series_cython.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/modform/l_series_gross_zagier_coeffs.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/modsym/apply.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/modsym/heilbronn.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/modsym/manin_symbol.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/modsym/p1list.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/modsym/relation_matrix_pyx.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modular/pollack_stevens/dist.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/finite_submodule_iter.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/free_module_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/module.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_complex_double_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_double_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_integer_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_integer_sparse.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_mod2_dense.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_modn_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_modn_sparse.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_rational_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_rational_sparse.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/vector_real_double_dense.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/modules/with_basis/indexed_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/monoids/free_abelian_monoid_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/cvxopt_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/cvxopt_sdp_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/generic_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/generic_sdp_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/glpk_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/glpk_exact_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/glpk_graph_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/interactivelp_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/matrix_sdp_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/backends/ppl_backend.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/gauss_legendre.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/linear_functions.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/linear_tensor_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/mip.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/numerical/sdp.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/plot/complex_plot.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/plot/plot3d/base.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/plot/plot3d/implicit_surface.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/plot/plot3d/index_face_set.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/plot/plot3d/parametric_surface.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/plot/plot3d/shapes.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/plot/plot3d/transform.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/probability/probability_distribution.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/quadratic_forms/count_local_2.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/quadratic_forms/quadratic_form__evaluate.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/quadratic_forms/ternary.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/quivers/algebra_elements.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/quivers/paths.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/bernmm.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/bernoulli_mod_p.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/complex_arb.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/complex_double.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/complex_interval.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/complex_mpc.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/complex_mpfr.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/complex_number.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/convert/mpfi.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/factorint.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/fast_arith.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/element_base.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/element_givaro.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/element_ntl_gf2e.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/element_pari_ffelt.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/finite_field_base.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/hom_finite_field.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/hom_finite_field_givaro.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/hom_prime_finite_field.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/integer_mod.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/finite_rings/residue_field.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/fraction_field_FpT.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/fraction_field_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/function_field/element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/integer.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/integer_ring.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/laurent_series_ring_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/morphism.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/noncommutative_ideals.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/number_field/number_field_base.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/number_field/number_field_element.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/number_field/number_field_element_quadratic.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/number_field/number_field_morphisms.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/number_field/totallyreal.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/number_field/totallyreal_data.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/common_conversion.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/local_generic_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/morphism.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_ZZ_pX_CA_element.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_ZZ_pX_CR_element.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_ZZ_pX_FM_element.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_ZZ_pX_element.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_capped_absolute_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_capped_relative_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_ext_element.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_fixed_mod_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_floating_point_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_generic_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/padic_printing.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/pow_computer.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/pow_computer_ext.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/pow_computer_flint.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/pow_computer_relative.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/qadic_flint_CA.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/qadic_flint_CR.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/qadic_flint_FM.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/qadic_flint_FP.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/relative_ramified_CA.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/relative_ramified_CR.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/relative_ramified_FM.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/padics/relative_ramified_FP.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/cyclotomic.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/evaluation_flint.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/evaluation_ntl.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/hilbert.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/laurent_polynomial.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/multi_polynomial.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/multi_polynomial_ideal_libsingular.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/multi_polynomial_libsingular.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/multi_polynomial_ring_base.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/ore_polynomial_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/pbori/pbori.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/plural.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polydict.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polynomial_compiled.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polynomial_complex_arb.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polynomial_element.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polynomial_gf2x.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polynomial_integer_dense_flint.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polynomial_integer_dense_ntl.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polynomial_modn_dense_ntl.cpp'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polynomial_number_field.c'
# patching b'/content/SageMath/build/pkgs/sagelib/src/build/cythonized/sage/rings/polynomial/polynomial_rational_flint.cpp'
# ...
# patching b'/content/SageMath/local/share/terminfo/m/mai'
# patching b'/content/SageMath/local/share/terminfo/m/mt4520-rv'
# patching b'/content/SageMath/local/share/terminfo/n/ncsa'
# patching b'/content/SageMath/local/share/terminfo/n/ncsa-m'
# patching b'/content/SageMath/local/share/terminfo/n/ncsa-m-ns'
# patching b'/content/SageMath/local/share/terminfo/n/ncsa-ns'
# patching b'/content/SageMath/local/share/terminfo/n/ncsa-vt220'
# patching b'/content/SageMath/local/share/terminfo/n/ncsa-vt220-8'
# patching b'/content/SageMath/local/share/terminfo/n/netbsd6'
# patching b'/content/SageMath/local/share/terminfo/n/news'
# patching b'/content/SageMath/local/share/terminfo/n/news-29'
# patching b'/content/SageMath/local/share/terminfo/n/news-29-euc'
# patching b'/content/SageMath/local/share/terminfo/n/news-29-sjis'
# patching b'/content/SageMath/local/share/terminfo/n/news-33'
# patching b'/content/SageMath/local/share/terminfo/n/news-33-euc'
# patching b'/content/SageMath/local/share/terminfo/n/news-33-sjis'
# patching b'/content/SageMath/local/share/terminfo/n/news-42'
# patching b'/content/SageMath/local/share/terminfo/n/news-42-euc'
# patching b'/content/SageMath/local/share/terminfo/n/news-42-sjis'
# patching b'/content/SageMath/local/share/terminfo/n/news-a'
# patching b'/content/SageMath/local/share/terminfo/n/news-o'
# patching b'/content/SageMath/local/share/terminfo/n/news-old-unk'
# patching b'/content/SageMath/local/share/terminfo/n/news-unk'
# patching b'/content/SageMath/local/share/terminfo/n/news28'
# patching b'/content/SageMath/local/share/terminfo/n/news28-a'
# patching b'/content/SageMath/local/share/terminfo/n/news29'
# patching b'/content/SageMath/local/share/terminfo/n/news31'
# patching b'/content/SageMath/local/share/terminfo/n/news31-a'
# patching b'/content/SageMath/local/share/terminfo/n/news31-o'
# patching b'/content/SageMath/local/share/terminfo/n/news33'
# patching b'/content/SageMath/local/share/terminfo/n/news40'
# patching b'/content/SageMath/local/share/terminfo/n/news40-a'
# patching b'/content/SageMath/local/share/terminfo/n/news40-o'
# patching b'/content/SageMath/local/share/terminfo/n/news42'
# patching b'/content/SageMath/local/share/terminfo/n/newscbm'
# patching b'/content/SageMath/local/share/terminfo/n/newscbm-a'
# patching b'/content/SageMath/local/share/terminfo/n/newscbm-o'
# patching b'/content/SageMath/local/share/terminfo/n/newscbm33'
# patching b'/content/SageMath/local/share/terminfo/n/nwe501'
# patching b'/content/SageMath/local/share/terminfo/n/nwe501-a'
# patching b'/content/SageMath/local/share/terminfo/n/nwe501-o'
# patching b'/content/SageMath/local/share/terminfo/n/nwp-517'
# patching b'/content/SageMath/local/share/terminfo/n/nwp-517-w'
# patching b'/content/SageMath/local/share/terminfo/n/nwp251-a'
# patching b'/content/SageMath/local/share/terminfo/n/nwp251-o'
# patching b'/content/SageMath/local/share/terminfo/n/nwp512'
# patching b'/content/SageMath/local/share/terminfo/n/nwp512-a'
# patching b'/content/SageMath/local/share/terminfo/n/nwp512-o'
# patching b'/content/SageMath/local/share/terminfo/n/nwp513'
# patching b'/content/SageMath/local/share/terminfo/n/nwp513-a'
# patching b'/content/SageMath/local/share/terminfo/n/nwp513-o'
# patching b'/content/SageMath/local/share/terminfo/n/nwp514'
# patching b'/content/SageMath/local/share/terminfo/n/nwp514-a'
# patching b'/content/SageMath/local/share/terminfo/n/nwp514-o'
# patching b'/content/SageMath/local/share/terminfo/n/nwp517'
# patching b'/content/SageMath/local/share/terminfo/n/nwp517-w'
# patching b'/content/SageMath/local/share/terminfo/n/nwp518'
# patching b'/content/SageMath/local/share/terminfo/n/nwp518-a'
# patching b'/content/SageMath/local/share/terminfo/n/nwp518-o'
# patching b'/content/SageMath/local/share/terminfo/o/o85h'
# patching b'/content/SageMath/local/share/terminfo/o/oabm85h'
# patching b'/content/SageMath/local/share/terminfo/o/opus3n1+'
# patching b'/content/SageMath/local/share/terminfo/o/otek4115'
# patching b'/content/SageMath/local/share/terminfo/p/pcmw'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt25'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt25-color'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt25w'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt28'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt28w'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt35'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt35w'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt40'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt40w'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt43'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt43w'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt50'
# patching b'/content/SageMath/local/share/terminfo/p/pcvt50w'
# patching b'/content/SageMath/local/share/terminfo/p/pcvtXX'
# patching b'/content/SageMath/local/share/terminfo/r/rebus3180'
# patching b'/content/SageMath/local/share/terminfo/t/ti916'
# patching b'/content/SageMath/local/share/terminfo/t/ti916-132'
# patching b'/content/SageMath/local/share/terminfo/t/ti916-220-7'
# patching b'/content/SageMath/local/share/terminfo/t/ti916-220-8'
# patching b'/content/SageMath/local/share/terminfo/t/ti916-8'
# patching b'/content/SageMath/local/share/terminfo/t/ti916-8-132'
# patching b'/content/SageMath/local/share/terminfo/t/tvi9065'
# patching b'/content/SageMath/local/share/terminfo/t/tvi910'
# patching b'/content/SageMath/local/share/terminfo/t/tvi910+'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-2p-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-2p-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-2p-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-mc-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-mc-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-p-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-p-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-unk-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-unk-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-vb-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-vb-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912b-vb-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-2p-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-2p-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-2p-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-mc-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-mc-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-p-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-p-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-unk-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-unk-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-vb-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-vb-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912c-vb-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi912cc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi914'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-2p-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-2p-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-2p-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-mc-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-mc-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-p-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-p-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-unk-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-unk-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-vb-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-vb-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920b-vb-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-2p-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-2p-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-2p-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-mc-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-mc-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-p-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-p-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-unk-2p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-unk-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-vb'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-vb-mc'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-vb-p'
# patching b'/content/SageMath/local/share/terminfo/t/tvi920c-vb-unk'
# patching b'/content/SageMath/local/share/terminfo/t/tvi921'
# patching b'/content/SageMath/local/share/terminfo/t/tvi924'
# patching b'/content/SageMath/local/share/terminfo/t/tvi92B'
# patching b'/content/SageMath/local/share/terminfo/t/tvi92D'
# patching b'/content/SageMath/local/share/terminfo/t/tvipt'
# patching b'/content/SageMath/local/share/terminfo/u/ultima2'
# patching b'/content/SageMath/local/share/terminfo/u/ultimaII'
# patching b'/content/SageMath/local/share/terminfo/u/uniterm'
# patching b'/content/SageMath/local/share/terminfo/u/uniterm49'
# patching b'/content/SageMath/local/share/terminfo/u/uts30'
# patching b'/content/SageMath/local/share/terminfo/v/v200-nam'
# patching b'/content/SageMath/local/share/terminfo/v/v320n'
# patching b'/content/SageMath/local/share/terminfo/v/versaterm'
# patching b'/content/SageMath/local/share/terminfo/v/vt100-bm'
# patching b'/content/SageMath/local/share/terminfo/v/vt100-bm-o'
# patching b'/content/SageMath/local/share/terminfo/v/vt200'
# patching b'/content/SageMath/local/share/terminfo/v/vt200-8'
# patching b'/content/SageMath/local/share/terminfo/v/vt200-8bit'
# patching b'/content/SageMath/local/share/terminfo/v/vt200-js'
# patching b'/content/SageMath/local/share/terminfo/v/vt200-old'
# patching b'/content/SageMath/local/share/terminfo/v/vt200-w'
# patching b'/content/SageMath/local/share/terminfo/v/vt220'
# patching b'/content/SageMath/local/share/terminfo/v/vt220-8'
# patching b'/content/SageMath/local/share/terminfo/v/vt220-8bit'
# patching b'/content/SageMath/local/share/terminfo/v/vt220-js'
# patching b'/content/SageMath/local/share/terminfo/v/vt220-nam'
# patching b'/content/SageMath/local/share/terminfo/v/vt220-old'
# patching b'/content/SageMath/local/share/terminfo/v/vt220-w'
# patching b'/content/SageMath/local/share/terminfo/v/vt220d'
# patching b'/content/SageMath/local/share/terminfo/v/vt300'
# patching b'/content/SageMath/local/share/terminfo/v/vt300-nam'
# patching b'/content/SageMath/local/share/terminfo/v/vt300-w'
# patching b'/content/SageMath/local/share/terminfo/v/vt300-w-nam'
# patching b'/content/SageMath/local/share/terminfo/v/vt320'
# patching b'/content/SageMath/local/share/terminfo/v/vt320-k311'
# patching b'/content/SageMath/local/share/terminfo/v/vt320-nam'
# patching b'/content/SageMath/local/share/terminfo/v/vt320-w'
# patching b'/content/SageMath/local/share/terminfo/v/vt320-w-nam'
# patching b'/content/SageMath/local/share/terminfo/v/vt320nam'
# patching b'/content/SageMath/local/share/terminfo/v/vt330'
# patching b'/content/SageMath/local/share/terminfo/v/vt340'
# patching b'/content/SageMath/local/share/terminfo/v/vt400'
# patching b'/content/SageMath/local/share/terminfo/v/vt400-24'
# patching b'/content/SageMath/local/share/terminfo/v/vt420'
# patching b'/content/SageMath/local/share/terminfo/v/vt420f'
# patching b'/content/SageMath/local/share/terminfo/v/vt420pc'
# patching b'/content/SageMath/local/share/terminfo/v/vt420pcdos'
# patching b'/content/SageMath/local/share/terminfo/v/vt510'
# patching b'/content/SageMath/local/share/terminfo/v/vt510pc'
# patching b'/content/SageMath/local/share/terminfo/v/vt510pcdos'
# patching b'/content/SageMath/local/share/terminfo/v/vt520'
# patching b'/content/SageMath/local/share/terminfo/v/vt520ansi'
# patching b'/content/SageMath/local/share/terminfo/v/vt525'
# patching b'/content/SageMath/local/share/terminfo/w/wsvt25'
# patching b'/content/SageMath/local/share/terminfo/w/wsvt25m'
# patching b'/content/SageMath/local/share/terminfo/x/x68k'
# patching b'/content/SageMath/local/share/terminfo/x/x68k-ite'
# patching b'/content/SageMath/local/share/terminfo/z/z29a'
# patching b'/content/SageMath/local/share/terminfo/z/z29a-kc-bc'
# patching b'/content/SageMath/local/share/terminfo/z/z29a-kc-uc'
# patching b'/content/SageMath/local/share/terminfo/z/z29a-nkc-bc'
# patching b'/content/SageMath/local/share/terminfo/z/z29a-nkc-uc'
# patching b'/content/SageMath/local/share/terminfo/z/z340'
# patching b'/content/SageMath/local/share/terminfo/z/z340-nam'
# patching b'/content/SageMath/local/var/lib/sage/scripts/gap/spkg-prerm'
# patching b'/content/SageMath/local/var/lib/sage/scripts/gcc/spkg-postrm'
# patching b'/content/SageMath/local/var/lib/sage/scripts/pplpy/spkg-postrm'
# patching b'/content/SageMath/src/bin/sage-env-config'
# patching b'/content/SageMath/src/bin/sage-src-env-config'
# patching b'/content/SageMath/src/sage/ext/interpreters/__init__.py'
# patching b'/content/SageMath/src/sage/ext/interpreters/interp_cc.c'
# patching b'/content/SageMath/src/sage/ext/interpreters/interp_cdf.c'
# patching b'/content/SageMath/src/sage/ext/interpreters/interp_el.c'
# patching b'/content/SageMath/src/sage/ext/interpreters/interp_py.c'
# patching b'/content/SageMath/src/sage/ext/interpreters/interp_rdf.c'
# patching b'/content/SageMath/src/sage/ext/interpreters/interp_rr.c'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_cc.pxd'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_cc.pyx'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_cdf.pxd'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_cdf.pyx'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_el.pxd'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_el.pyx'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_py.pxd'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_py.pyx'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_rdf.pxd'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_rdf.pyx'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_rr.pxd'
# patching b'/content/SageMath/src/sage/ext/interpreters/wrapper_rr.pyx'

# %%
# !pip3 install bitcoin
# Out:
# Collecting bitcoin
#   Downloading bitcoin-1.1.42.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bitcoin
#   Building wheel for bitcoin (setup.py) ... done
#   Created wheel for bitcoin: filename=bitcoin-1.1.42-py3-none-any.whl size=44402 sha256=2c87776ff13a5d7f24685ebf6d89a6da9dc99fb778896c66c3f1640898788369
#   Stored in directory: /root/.cache/pip/wheels/a3/98/a1/0d53f5b714680bb5dffc2db778c221b1f5c54bc4a3a779c8c5
# Successfully built bitcoin
# Installing collected packages: bitcoin
# Successfully installed bitcoin-1.1.42

# %%
# !pip3 install ecdsa
# Out:
# Collecting ecdsa
#   Downloading ecdsa-0.19.0-py2.py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.3/149.3 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from ecdsa) (1.16.0)
# Installing collected packages: ecdsa
# Successfully installed ecdsa-0.19.0

# %%
# !wget https://raw.githubusercontent.com/demining/CryptoDeepTools/main/20PolynonceAttack/crack_weak_ECDSA_nonces_with_LLL.py
# Out:
# --2024-04-18 05:47:39--  https://raw.githubusercontent.com/demining/CryptoDeepTools/main/20PolynonceAttack/crack_weak_ECDSA_nonces_with_LLL.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2607 (2.5K) [text/plain]
# Saving to: ‘crack_weak_ECDSA_nonces_with_LLL.py’
#
# crack_weak_ECDSA_no 100%[===================>]   2.55K  --.-KB/s    in 0s
#
# 2024-04-18 05:47:39 (48.9 MB/s) - ‘crack_weak_ECDSA_nonces_with_LLL.py’ saved [2607/2607]

# %%
# !./sage -sh
